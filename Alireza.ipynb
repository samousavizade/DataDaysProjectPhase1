# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from datetime import datetime

# %%
df0 = pd.read_csv(
    "Data/time-series/0.csv",
    index_col="timestamp"
)

df0.index = datetime.fromtimestamp(df0.index)

df0.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 6>()
#       1 df0 = pd.read_csv(
#       2     "Data/time-series/0.csv",
#       3     index_col="timestamp"
#       4 )
# ----> 6 df0.index = datetime.fromtimestamp(df0.index)
#       8 df0.head()
#
# TypeError: 'Int64Index' object cannot be interpreted as an integer

# %%
plt.plot(
    df0.index,
    df0["value"]
)
